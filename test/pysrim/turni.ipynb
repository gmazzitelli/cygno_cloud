# %%
import pandas as pd
import numpy as np
people=["Amaro", 
        "Baracchini", 
        "Benussi", 
        "Bianco", 
        "Caponero",
        "DSCardoso", 
        "Cavoto", 
        "Costa", 
        "Roque", 
        "Dané", 
        "Dho", 
        "DiGiambattista", 
        "DiMarco", 
        "DImperio", 
        "Iacoangeli", 
        "HermanLima", 
        "GuilhermeLopes", 
        "AmarodaLopes", 
        "Maccarrone", 
        "Mano", 
        "Gregorio", 
        "Marques", 
        "Mazzitelli", 
        "McLean", 
        "Messina", 
        "Monteiro", 
        "Nobrega", 
        "Pains", 
        "Petrucci", 
        "Piacentini", 
        "Piccolo", 
        "Pinci", 
        "Prajapati", 
        "Renga", 
        "Santos", 
        "Saviano", 
        "Spooner", 
        "Torelli"]

# %%
print(len(people))
emptyArr = np.zeros(len(people), dtype=int)


data = {'person': people, 'enable': emptyArr, 'onsite': emptyArr, 'remote': emptyArr, 'local': emptyArr}

df = pd.DataFrame(data)
# Out:
# 38

# %%
df
# Out:
#             person  enable  onsite  remote  local
# 0            Amaro       0       0       0      0
# 1       Baracchini       0       0       0      0
# 2          Benussi       0       0       0      0
# 3           Bianco       0       0       0      0
# 4         Caponero       0       0       0      0
# 5        DSCardoso       0       0       0      0
# 6           Cavoto       0       0       0      0
# 7            Costa       0       0       0      0
# 8            Roque       0       0       0      0
# 9             Dané       0       0       0      0
# 10             Dho       0       0       0      0
# 11  DiGiambattista       0       0       0      0
# 12         DiMarco       0       0       0      0
# 13        DImperio       0       0       0      0
# 14      Iacoangeli       0       0       0      0
# 15      HermanLima       0       0       0      0
# 16  GuilhermeLopes       0       0       0      0
# 17    AmarodaLopes       0       0       0      0
# ...

# %%
for i, person in enumerate(people):
        df.loc[i,'enable'] = int(input(person+' enable:'))
        df.loc[i,'onsite'] = int(input(person+' onsite:'))
        df.loc[i,'remote'] = int(input(person+' remote:'))
        df.loc[i,'local'] = int(input(person+' local:'))

# %%
df
# Out:
#             person  enable  onsite  remote  local
# 0            Amaro       1       0       0      0
# 1       Baracchini       1       1       0      0
# 2          Benussi       1       0       0      0
# 3           Bianco       1       0       0      0
# 4         Caponero       1       0       0      0
# 5        DSCardoso       1       0       0      0
# 6           Cavoto       1       0       0      0
# 7            Costa       1       0       0      0
# 8            Roque       1       0       0      0
# 9             Dané       1       0       0      0
# 10             Dho       1       0       0      0
# 11  DiGiambattista       1       1       0      0
# 12         DiMarco       1       0       0      0
# 13        DImperio       1       0       0      0
# 14      Iacoangeli       1       0       0      0
# 15      HermanLima       1       0       0      0
# 16  GuilhermeLopes       1       0       0      0
# 17    AmarodaLopes       1       0       0      0
# ...
