# %%
# %run InitAndFuctions.ipynb
# Out:
# Host: d2255d2b1d02
# 3.6.8 (default, Nov 16 2020, 16:55:22)
# [GCC 4.8.5 20150623 (Red Hat 4.8.5-44)] <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f952f1f36a0>
# Welcome to JupyROOT 6.22/06

# %%
#
# init run and debug paramas
#
# Bandella 

# KFC cosmici
runI          = [4035]
run_ped       = 4034

# KFC Fe
runI          = [4039, 4040, 4041, 4042, 4043, 4044, 4045, 4046, 4047]
run_ped       = 4038

#runI          = [4045]
#run_ped       = 4038


# cimax         = 500 # normalemnte a 10 testa 500 per capire
# cimin         = 0 
# tag           = 'LAB'
# nsigma        = 1.5
# fiducial_cut  = 150 # pixel
# doRescale     = True
# debug         = False
# max_tarcks    = 20
# max_images    = -1 # -1 all 
# ###################################
# min_samples=2
# residual_threshold=3
# max_trials=1000
# random_state=42


runI          = [4045]
run_ped       = 4038

cimax         = 500
cimin         = 0 
tag           = 'LAB'
nsigma        = 0.5
fiducial_cut  = 150 # pixel
doRescale     = True
debug         = False
max_tarcks    = 20
max_images    = -1
###################################
min_samples=2
residual_threshold=2
max_trials=1000
random_state=42

# %%
run_info_logbook(runI[0], verbose=False)
# Out:
# File_Number                                        4045
# saved_events                                        200
# Exposure_Time_ms                                      1
# comments                          55Fe - Z = 36-1=35 cm
# Nominal_Flux_He_CF4                               60/40
# He_CF4                                              NaN
# Transfer_field_kV_cm                                2.5
# GEM3_V                                              430
# GEM2_V                                              440
# GEM1_V                                              440
# Calculated_GEM_stack_V                             1315
# Requested_Drift_field_V_cm                          960
# Calculated_Field_Cage_Anode_V                     316.8
# Real_Field_Cage_Anode_V                             317
# Calculated_Field_Cage_Catode_V                    49632
# Calculated_Drift_Field_V_cm                     960.004
# Name: 2967, dtype: object

# %%
version       = 'vL.1'
# %run CosmicsLine.ipynb
# Out:
# rascale:  4
# /workarea/cloud-storage/mazzitel/ped/run4038_mean.h5 /workarea/cloud-storage/mazzitel/ped/run4038_sigma.h5
# light over Th: 9815004.83
# Open file: /workarea/cloud-storage/cygnus/Data/LAB/histograms_Run04045.root
# Find Keys: 200
# # of Images (TH2) Files: 200
# # of Waveform (TH2) Files: 0
# Camera X, Y pixel: 2304 2304
# Processing RUN:  4045 Event:  0
# DEBUG: number of points, clusters: 7648 0
# ['iTr: 0.00', 'cluster_lable: 0.00', 'pixels: 7648.00', 'photons: 29620.13', 'ph_pixels: 3.87', 'x0start: 1740.00', 'y0start: 164.00', 'x0end: 292.00', 'y0end: 2132.00', 'length: 2443.30', 'mse: 1.71', 'r2: 1.00']
# (array([220.67364017, 301.60878661]), array([ 0.80889797, -0.58794904]))
# ph 29620, dim: 7648
# x,y start: 1740, 164, x,y stop: 292, 2132, length: 2443:
# Mean squared error: 1.71
# Coefficient of determination: 0.9997
# Elapsed time 10 events: 14.5
# Processing RUN:  4045 Event:  1
# Elapsed time 10 events: 13.3
# Processing RUN:  4045 Event:  2
# Elapsed time 10 events: 19.8
# Processing RUN:  4045 Event:  3
# Elapsed time 10 events: 15.0
# Processing RUN:  4045 Event:  4
# Elapsed time 10 events: 14.9
# Processing RUN:  4045 Event:  5
# Elapsed time 10 events: 14.5
# Processing RUN:  4045 Event:  6
# Elapsed time 10 events: 12.8
# Processing RUN:  4045 Event:  7
# Elapsed time 10 events: 17.0
# Processing RUN:  4045 Event:  8
# Elapsed time 10 events: 15.2
# Processing RUN:  4045 Event:  9
# Elapsed time 10 events: 15.7
# Processing RUN:  4045 Event:  10
# DEBUG: number of points, clusters: 10160 0
# ['iTr: 10.00', 'cluster_lable: 0.00', 'pixels: 10160.00', 'photons: 39497.41', 'ph_pixels: 3.89', 'x0start: 2120.00', 'y0start: 748.00', 'x0end: 168.00', 'y0end: 1880.00', 'length: 2256.49', 'mse: 3.62', 'r2: 1.00']
# (array([315.34488189, 308.6015748 ]), array([ 0.49657915, -0.86799144]))
# ph 39497, dim: 10160
# x,y start: 2120, 748, x,y stop: 168, 1880, length: 2256:
# Mean squared error: 3.62
# Coefficient of determination: 0.9997
# Elapsed time 10 events: 15.4
# Processing RUN:  4045 Event:  11
# Elapsed time 10 events: 13.5
# Processing RUN:  4045 Event:  12
# Elapsed time 10 events: 15.2
# Processing RUN:  4045 Event:  13
# Elapsed time 10 events: 14.7
# Processing RUN:  4045 Event:  14
# Elapsed time 10 events: 13.9
# Processing RUN:  4045 Event:  15
# Elapsed time 10 events: 14.8
# Processing RUN:  4045 Event:  16
# Elapsed time 10 events: 14.6
# Processing RUN:  4045 Event:  17
# Elapsed time 10 events: 14.9
# Processing RUN:  4045 Event:  18
# Elapsed time 10 events: 14.5
# Processing RUN:  4045 Event:  19
# Elapsed time 10 events: 15.7
# Processing RUN:  4045 Event:  20
# DEBUG: number of points, clusters: 8832 0
# ['iTr: 20.00', 'cluster_lable: 0.00', 'pixels: 8832.00', 'photons: 42268.03', 'ph_pixels: 4.79', 'x0start: 1480.00', 'y0start: 184.00', 'x0end: 2040.00', 'y0end: 2148.00', 'length: 2042.28', 'mse: 1.07', 'r2: 1.00']
# (array([241.36594203, 424.95833333]), array([0.96124526, 0.27569468]))
# ph 42268, dim: 8832
# x,y start: 1480, 184, x,y stop: 2040, 2148, length: 2042:
# Mean squared error: 1.07
# Coefficient of determination: 0.9983
# Elapsed time 10 events: 14.0
# Processing RUN:  4045 Event:  21
# Elapsed time 10 events: 12.8
# Processing RUN:  4045 Event:  22
# Elapsed time 10 events: 12.9
# Processing RUN:  4045 Event:  23
# Elapsed time 10 events: 16.3
# Processing RUN:  4045 Event:  24
# Elapsed time 10 events: 13.8
# Processing RUN:  4045 Event:  25
# Elapsed time 10 events: 15.4
# Processing RUN:  4045 Event:  26
# Elapsed time 10 events: 13.1
# Processing RUN:  4045 Event:  27
# Elapsed time 10 events: 17.2
# Processing RUN:  4045 Event:  28
# Elapsed time 10 events: 13.7
# Processing RUN:  4045 Event:  29
# Elapsed time 10 events: 15.3
# Processing RUN:  4045 Event:  30
# DEBUG: number of points, clusters: 11632 0
# ['iTr: 30.00', 'cluster_lable: 0.00', 'pixels: 11632.00', 'photons: 42076.42', 'ph_pixels: 3.62', 'x0start: 1268.00', 'y0start: 152.00', 'x0end: 348.00', 'y0end: 2152.00', 'length: 2201.45', 'mse: 1.41', 'r2: 1.00']
# (array([276.89821183, 206.8349381 ]), array([ 0.90963819, -0.41540145]))
# ph 42076, dim: 11632
# x,y start: 1268, 152, x,y stop: 348, 2152, length: 2201:
# Mean squared error: 1.41
# Coefficient of determination: 0.9995
# Elapsed time 10 events: 15.2
# Processing RUN:  4045 Event:  31
# Elapsed time 10 events: 14.7
# Processing RUN:  4045 Event:  32
# Elapsed time 10 events: 15.9
# Processing RUN:  4045 Event:  33
# Elapsed time 10 events: 15.7
# Processing RUN:  4045 Event:  34
# Elapsed time 10 events: 14.3
# Processing RUN:  4045 Event:  35
# Elapsed time 10 events: 15.3
# Processing RUN:  4045 Event:  36
# Elapsed time 10 events: 13.8
# Processing RUN:  4045 Event:  37
# Elapsed time 10 events: 13.3
# Processing RUN:  4045 Event:  38
# Elapsed time 10 events: 16.5
# Processing RUN:  4045 Event:  39
# Elapsed time 10 events: 15.5
# Processing RUN:  4045 Event:  40
# DEBUG: number of points, clusters: 7984 0
# ['iTr: 40.00', 'cluster_lable: 0.00', 'pixels: 7984.00', 'photons: 72731.15', 'ph_pixels: 9.11', 'x0start: 584.00', 'y0start: 160.00', 'x0end: 820.00', 'y0end: 2148.00', 'length: 2001.96', 'mse: 1.27', 'r2: 0.99']
# (array([216.42685371, 166.18837675]), array([0.99251273, 0.12214123]))
# ph 72731, dim: 7984
# x,y start: 584, 160, x,y stop: 820, 2148, length: 2002:
# Mean squared error: 1.27
# Coefficient of determination: 0.9888
# Elapsed time 10 events: 15.2
# Processing RUN:  4045 Event:  41
# Elapsed time 10 events: 15.4
# Processing RUN:  4045 Event:  42
# Elapsed time 10 events: 14.0
# Processing RUN:  4045 Event:  43
# Elapsed time 10 events: 17.0
# Processing RUN:  4045 Event:  44
# Elapsed time 10 events: 13.5
# Processing RUN:  4045 Event:  45
# Elapsed time 10 events: 13.5
# Processing RUN:  4045 Event:  46
# Elapsed time 10 events: 16.2
# Processing RUN:  4045 Event:  47
# Elapsed time 10 events: 14.6
# Processing RUN:  4045 Event:  48
# Elapsed time 10 events: 14.9
# Processing RUN:  4045 Event:  49
# Elapsed time 10 events: 17.1
# Processing RUN:  4045 Event:  50
# DEBUG: number of points, clusters: 8816 0
# ['iTr: 50.00', 'cluster_lable: 0.00', 'pixels: 8816.00', 'photons: 38325.74', 'ph_pixels: 4.35', 'x0start: 1132.00', 'y0start: 148.00', 'x0end: 1156.00', 'y0end: 2116.00', 'length: 1968.15', 'mse: 1.19', 'r2: 0.77']
# (array([260.23774955, 285.57350272]), array([0.99986972, 0.01614151]))
# ph 38326, dim: 8816
# x,y start: 1132, 148, x,y stop: 1156, 2116, length: 1968:
# Mean squared error: 1.19
# Coefficient of determination: 0.7748
# Elapsed time 10 events: 14.5
# Processing RUN:  4045 Event:  51
# Elapsed time 10 events: 14.1
# Processing RUN:  4045 Event:  52
# Elapsed time 10 events: 14.7
# Processing RUN:  4045 Event:  53
# Elapsed time 10 events: 14.0
# Processing RUN:  4045 Event:  54
# Elapsed time 10 events: 13.6
# Processing RUN:  4045 Event:  55
# Elapsed time 10 events: 14.2
# Processing RUN:  4045 Event:  56
# Elapsed time 10 events: 16.7
# Processing RUN:  4045 Event:  57
# Elapsed time 10 events: 15.0
# Processing RUN:  4045 Event:  58
# Elapsed time 10 events: 15.8
# Processing RUN:  4045 Event:  59
# Elapsed time 10 events: 14.8
# Processing RUN:  4045 Event:  60
# DEBUG: number of points, clusters: 7616 0
# ['iTr: 60.00', 'cluster_lable: 0.00', 'pixels: 7616.00', 'photons: 26617.65', 'ph_pixels: 3.49', 'x0start: 2068.00', 'y0start: 184.00', 'x0end: 1036.00', 'y0end: 2124.00', 'length: 2197.41', 'mse: 1.33', 'r2: 1.00']
# (array([311.44957983, 374.95378151]), array([ 0.88310199, -0.46918108]))
# ph 26618, dim: 7616
# x,y start: 2068, 184, x,y stop: 1036, 2124, length: 2197:
# Mean squared error: 1.33
# Coefficient of determination: 0.9996
# Elapsed time 10 events: 16.3
# Processing RUN:  4045 Event:  61
# Elapsed time 10 events: 14.8
# Processing RUN:  4045 Event:  62
# Elapsed time 10 events: 14.7
# Processing RUN:  4045 Event:  63
# Elapsed time 10 events: 16.6
# Processing RUN:  4045 Event:  64
# Elapsed time 10 events: 15.1
# Processing RUN:  4045 Event:  65
# Elapsed time 10 events: 15.3
# Processing RUN:  4045 Event:  66
# Elapsed time 10 events: 15.8
# Processing RUN:  4045 Event:  67
# Elapsed time 10 events: 14.0
# Processing RUN:  4045 Event:  68
# Elapsed time 10 events: 14.9
# Processing RUN:  4045 Event:  69
# Elapsed time 10 events: 16.3
# Processing RUN:  4045 Event:  70
# DEBUG: number of points, clusters: 8912 0
# ['iTr: 70.00', 'cluster_lable: 0.00', 'pixels: 8912.00', 'photons: 34955.40', 'ph_pixels: 3.92', 'x0start: 1164.00', 'y0start: 164.00', 'x0end: 1676.00', 'y0end: 2152.00', 'length: 2052.87', 'mse: 1.04', 'r2: 1.00']
# (array([260.75224417, 347.01795332]), array([0.96828495, 0.24984848]))
# ph 34955, dim: 8912
# x,y start: 1164, 164, x,y stop: 1676, 2152, length: 2053:
# Mean squared error: 1.04
# Coefficient of determination: 0.9987
# Elapsed time 10 events: 16.5
# Processing RUN:  4045 Event:  71
# Elapsed time 10 events: 14.1
# Processing RUN:  4045 Event:  72
# Elapsed time 10 events: 15.9
# Processing RUN:  4045 Event:  73
# Elapsed time 10 events: 14.1
# Processing RUN:  4045 Event:  74
# Elapsed time 10 events: 17.8
# Processing RUN:  4045 Event:  75
# Elapsed time 10 events: 14.4
# Processing RUN:  4045 Event:  76

# %%
sns.set_context("paper", rc={"font.size":18,"axes.titlesize":18,"axes.labelsize":14})   
fig, ax = plt.subplots(1,1, figsize=(10,5))
proj_xy(edges, y=False)
ax.axvline(fiducial_cut, color='k')
ax.axvline(edges.shape[0]-fiducial_cut, color='k')
plt.show()

# %% [markdown]
# # debug

# %%
fig, ax = plt.subplots (1,2, figsize=(20,10))
ax[0].imshow(rebin_image, cmap='jet', vmin=0, vmax=20)
ax[1].imshow(edges, cmap='YlGnBu', vmin=0,vmax=1)
ax[1].plot(xc, yc, '.g', alpha=0.6,
label='Inlier data', markersize=6)
ax[1].plot(line_y_robust, line_x, '--r', label='Robust line model')
ax[1].set_xlim(0,rebin_image.shape[1]-1)
ax[1].set_ylim(rebin_image.shape[0]-1,0)
plt.show()

# %%
def n_tarp(x, y, ax, image = np.array([]), n_std=3.0, facecolor='none', **kwargs):
    from matplotlib.patches import Rectangle
    mean_x = x.mean()
    mean_y = y.mean()
    std_x = x.std()
    std_y = y.std()
    half_width = n_std * std_x
    half_height = n_std * std_y
    if image.any():
        rimage = image*0
        xs = int(mean_x - half_width)+1
        xe = int(mean_x + half_width)+1
        ys = int(mean_y - half_height)+1
        ye = int(mean_y + half_height)+1
        # print(ys,ye, xs,xe)
        rimage[ys:ye, xs:xe]=image[ys:ye, xs:xe]
        # print (rimage)
        # print(rimage.sum())
        
    rectangle = Rectangle(
        (mean_x - half_width, mean_y - half_height),
        2 * half_width, 2 * half_height, facecolor=facecolor, **kwargs)
    return ax.add_patch(rectangle), rimage  


def n_std_rectangle(x, y, ax, image = np.array([]), n_std=3.0, facecolor='none', **kwargs):
    from matplotlib.patches import Rectangle
    mean_x = x.mean()
    mean_y = y.mean()
    std_x = x.std()
    std_y = y.std()
    half_width = n_std * std_x
    half_height = n_std * std_y
    if image.any():
        rimage = image*0
        xs = int(mean_x - half_width)+1
        xe = int(mean_x + half_width)+1
        ys = int(mean_y - half_height)+1
        ye = int(mean_y + half_height)+1
        # print(ys,ye, xs,xe)
        rimage[ys:ye, xs:xe]=image[ys:ye, xs:xe]
        # print (rimage)
        # print(rimage.sum())
        
    rectangle = Rectangle(
        (mean_x - half_width, mean_y - half_height),
        2 * half_width, 2 * half_height, facecolor=facecolor, **kwargs)
    return ax.add_patch(rectangle), rimage  

def confidence_ellipse(x, y, ax, image = np.array([]), n_std=3.0, facecolor='none', **kwargs):
    from matplotlib.patches import Ellipse
    import matplotlib.transforms as transforms
    import numpy as np

    if x.size != y.size:
        raise ValueError("x and y must be the same size")

    cov = np.cov(x, y)
    pearson = cov[0, 1]/np.sqrt(cov[0, 0] * cov[1, 1])
    # Using a special case to obtain the eigenvalues of this
    # two-dimensionl dataset.
    ell_radius_x = np.sqrt(1 + pearson)
    ell_radius_y = np.sqrt(1 - pearson)
    ellipse = Ellipse((0, 0),
        width=ell_radius_x * 2,
        height=ell_radius_y * 2,
        facecolor=facecolor,
        **kwargs)

    # Calculating the stdandard deviation of x from
    # the squareroot of the variance and multiplying
    # with the given number of standard deviations.
    scale_x = np.sqrt(cov[0, 0]) * n_std
    mean_x = np.mean(x)

    # calculating the stdandard deviation of y ...
    scale_y = np.sqrt(cov[1, 1]) * n_std
    mean_y = np.mean(y)
    if image.any():
        # ellsisse e' (x-x0)**2/a**2 + (y-y0)**2/b**2 < 1
        # print (mean_x, mean_y, ell_radius_x*scale_x, ell_radius_y*scale_y)
        rimage = image*0
        ar = abs(pearson)
        for x in range(image.shape[1]):
            for y in range(image.shape[0]):
                xr = (y-mean_y)*np.sin(ar)+(x-mean_x)*np.cos(ar)
                yr = (y-mean_y)*np.cos(ar)-(x-mean_x)*np.sin(ar)
                if (xr)**2/(ell_radius_x*scale_x)**2 + (yr)**2/(ell_radius_y*scale_y)**2 < 1:
                    rimage[y,x]=image[y, x]
        # print (rimage)
        # print(rimage.sum())
    
    transf = transforms.Affine2D() \
        .rotate_deg(45) \
        .scale(scale_x, scale_y) \
        .translate(mean_x, mean_y)

    ellipse.set_transform(transf + ax.transData)

    return ax.add_patch(ellipse), rimage 


def confidence_ellipse_par(x, y, image = np.array([]), n_std=3.0, facecolor='none', **kwargs):
    import numpy as np

    if x.size != y.size:
        raise ValueError("x and y must be the same size")

    cov = np.cov(x, y)
    pearson = cov[0, 1]/np.sqrt(cov[0, 0] * cov[1, 1])

    ell_radius_x = np.sqrt(1 + pearson)
    ell_radius_y = np.sqrt(1 - pearson)
                           
    scale_x = np.sqrt(cov[0, 0]) * n_std
    mean_x = np.mean(x)

    scale_y = np.sqrt(cov[1, 1]) * n_std
    mean_y = np.mean(y)
                           
    width=scale_x*ell_radius_x * 2 
    height=scale_y*ell_radius_y * 2              
    if image.any():
        # ellsisse e' (x-x0)**2/a**2 + (y-y0)**2/b**2 < 1
        # print (mean_x, mean_y, ell_radius_x*scale_x, ell_radius_y*scale_y)
        rimage = image*0
        ar = abs(pearson)
        for x in range(image.shape[1]):
            for y in range(image.shape[0]):
                xr = (y-mean_y)*np.sin(ar)+(x-mean_x)*np.cos(ar)
                yr = (y-mean_y)*np.cos(ar)-(x-mean_x)*np.sin(ar)
                if (xr)**2/(ell_radius_x*scale_x)**2 + (yr)**2/(ell_radius_y*scale_y)**2 < 1:
                    rimage[y,x]=image[y, x]
        # print (rimage)
        # print(rimage.sum())
    else:
        rimage = np.array([])

    
    return width, height, pearson, rimage.sum(), np.size(rimage[rimage>0])

# %%
for k in range(10):
    for i in range(xc.shape[0]):
        edges[int(yc[i]), int(xc[i])]=0
    points          = np.array(np.nonzero(edges)).T.astype(float)
    model = LineModelND()
    model.estimate(points)

    # robustly fit line only using inlier data with RANSAC algorithm
    model_robust, inliers = ransac(points, LineModelND, min_samples=2,
                                   residual_threshold=1, max_trials=1000)
    outliers = inliers == False

    # generate coordinates of estimated models
    line_x = np.arange(0, rebin_image.shape[1])
    line_y = model.predict_y(line_x)
    line_y_robust = model_robust.predict_y(line_x)

    xc = points[inliers, 1]
    yc = points[inliers, 0]
    fig, ax = plt.subplots (1,2, figsize=(20,10))
    ax[0].imshow(rebin_image, cmap='jet', vmin=0, vmax=20)
    ax[1].imshow(edges, cmap='YlGnBu', vmin=0,vmax=1)
    ax[1].plot(xc, yc, '.g', alpha=0.6,
    label='Inlier data', markersize=6)
    ax[1].plot(line_y_robust, line_x, '--r', label='Robust line model')
    ax[1].set_xlim(0,rebin_image.shape[1]-1)
    ax[1].set_ylim(rebin_image.shape[0]-1,0)
    plt.show()
