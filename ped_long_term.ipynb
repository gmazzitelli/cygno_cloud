# %%
# %run InitAndFuctions.ipynb
# Out:
# Host: 2302e5a928e2
# 3.6.8 (default, Nov 16 2020, 16:55:22)
# [GCC 4.8.5 20150623 (Red Hat 4.8.5-44)] <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f36d1fdc630>
# Welcome to JupyROOT 6.22/06

# %%
for run in range(5300, 5313):
    df = cy.run_info_logbook(run, sql=True, verbose=True)
    if "Pedestal, random" in df[df.varible=="RunDescription"].values[0][1]:
        print (df)
        m_image, s_image = cy.ped_(run, path=mybasepath+'ped/')
# Out:
#              varible                                              value
# 0         Run number                                               5301
# 1     RunDescription  Pedestal, random trigger 21 Hz, long exposure ...
# 2         Start time                                2021-10-24 03:10:16
# 3          Stop time                                2021-10-24 03:14:35
# 4   Number of events                                                102
# 5       Exposure_sec                                                  1
# 6           OFFSET_V                                                  0
# 7             GEM3_V                                                440
# 8             GEM2_V                                                440
# 9             GEM1_V                                                440
# 10              T2_V                                                500
# 11              T1_V                                                500
# 12           DRIFT_V                                                840
# 13          HV_STATE                                                  1
# 14    GEMGeometry_id                                                  0
# /workarea/private/ped/run5301_mean.h5 /workarea/private/ped/run5301_sigma.h5
# >>> Pedestal Maker! <<<
# Open file: https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-data/LAB/histograms_Run05301.root
# Find Keys: 8262
# # of Images (TH2) Files: 102
# # of Waveform (TH2) Files: 8160
# Camera X, Y pixel: 2304 2304
# WARNING: pdestal from 0 to 102
# Debug Image[200,200]: 10 => 105.00 7.83 106.82
# Debug Image[200,200]: 20 => 102.00 7.98 105.10
# Debug Image[200,200]: 30 => 114.00 7.43 104.26
# Debug Image[200,200]: 40 => 102.00 6.75 104.22
# Debug Image[200,200]: 50 => 108.00 6.51 103.53
# Debug Image[200,200]: 60 => 95.00 6.48 102.92
# Debug Image[200,200]: 70 => 111.00 6.32 102.68
# Debug Image[200,200]: 80 => 89.00 6.35 102.52
# Debug Image[200,200]: 90 => 109.00 6.37 102.96
# Debug Image[200,200]: 100 => 114.00 6.57 103.14
# sigma 6.539911
# DONE OUTPUT on files: %s, %s ('/workarea/private/ped/run5301_mean.h5', '/workarea/private/ped/run5301_sigma.h5')
#              varible                                              value
# 0         Run number                                               5303
# 1     RunDescription  Pedestal, random trigger 21 Hz, long exposure ...
# 2         Start time                                2021-10-24 04:15:27
# 3          Stop time                                2021-10-24 04:19:46
# 4   Number of events                                                102
# 5       Exposure_sec                                                  1
# 6           OFFSET_V                                                  0
# 7             GEM3_V                                                440
# 8             GEM2_V                                                440
# 9             GEM1_V                                                440
# 10              T2_V                                                500
# 11              T1_V                                                500
# 12           DRIFT_V                                                840
# 13          HV_STATE                                                  1
# 14    GEMGeometry_id                                                  0
# /workarea/private/ped/run5303_mean.h5 /workarea/private/ped/run5303_sigma.h5
# >>> Pedestal Maker! <<<
# Open file: https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-data/LAB/histograms_Run05303.root
# Find Keys: 8262
# # of Images (TH2) Files: 102
# # of Waveform (TH2) Files: 8160
# Camera X, Y pixel: 2304 2304
# WARNING: pdestal from 0 to 102
# Debug Image[200,200]: 10 => 93.00 7.93 100.73
# Debug Image[200,200]: 20 => 101.00 6.67 101.33
# Debug Image[200,200]: 30 => 105.00 6.78 103.10
# Debug Image[200,200]: 40 => 117.00 6.90 103.34
# Debug Image[200,200]: 50 => 103.00 6.66 103.47
# Debug Image[200,200]: 60 => 107.00 6.38 103.57
# Debug Image[200,200]: 70 => 101.00 6.51 103.70
# Debug Image[200,200]: 80 => 111.00 6.68 103.79
# Debug Image[200,200]: 90 => 98.00 6.67 103.71
# Debug Image[200,200]: 100 => 91.00 6.63 103.55
# sigma 6.603984
# DONE OUTPUT on files: %s, %s ('/workarea/private/ped/run5303_mean.h5', '/workarea/private/ped/run5303_sigma.h5')
#              varible                                              value
# 0         Run number                                               5305
# 1     RunDescription  Pedestal, random trigger 21 Hz, long exposure ...
# 2         Start time                                2021-10-24 05:20:38
# 3          Stop time                                2021-10-24 05:24:57
# 4   Number of events                                                104
# 5       Exposure_sec                                                  1
# 6           OFFSET_V                                                  0
# 7             GEM3_V                                                440
# 8             GEM2_V                                                440
# 9             GEM1_V                                                440
# 10              T2_V                                                500
# 11              T1_V                                                500
# 12           DRIFT_V                                                840
# 13          HV_STATE                                                  1
# 14    GEMGeometry_id                                                  0
# /workarea/private/ped/run5305_mean.h5 /workarea/private/ped/run5305_sigma.h5
# >>> Pedestal Maker! <<<
# Open file: https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-data/LAB/histograms_Run05305.root
# Find Keys: 8424
# # of Images (TH2) Files: 104
# # of Waveform (TH2) Files: 8320
# Camera X, Y pixel: 2304 2304
# WARNING: pdestal from 0 to 104
# Debug Image[200,200]: 10 => 97.00 7.15 105.45
# Debug Image[200,200]: 20 => 96.00 7.26 104.95
# Debug Image[200,200]: 30 => 106.00 6.38 104.84
# Debug Image[200,200]: 40 => 96.00 6.10 104.10
# Debug Image[200,200]: 50 => 105.00 6.03 103.96
# Debug Image[200,200]: 60 => 103.00 6.13 104.07
# Debug Image[200,200]: 70 => 100.00 6.11 103.61
# Debug Image[200,200]: 80 => 104.00 6.16 103.79
# Debug Image[200,200]: 90 => 103.00 6.22 103.73
# Debug Image[200,200]: 100 => 122.00 6.44 103.71
# sigma 6.516015
# DONE OUTPUT on files: %s, %s ('/workarea/private/ped/run5305_mean.h5', '/workarea/private/ped/run5305_sigma.h5')
#              varible                                              value
# 0         Run number                                               5307
# 1     RunDescription  Pedestal, random trigger 21 Hz, short exposure...
# 2         Start time                                2021-10-24 05:28:47
# 3          Stop time                                2021-10-24 05:30:31
# 4   Number of events                                                101
# 5       Exposure_sec                                               0.05
# 6           OFFSET_V                                                  0
# 7             GEM3_V                                                440
# 8             GEM2_V                                                440
# 9             GEM1_V                                                440
# 10              T2_V                                                500
# 11              T1_V                                                500
# 12           DRIFT_V                                                840
# 13          HV_STATE                                                  0
# 14    GEMGeometry_id                                                  0
# /workarea/private/ped/run5307_mean.h5 /workarea/private/ped/run5307_sigma.h5
# >>> Pedestal Maker! <<<
# Open file: https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-data/LAB/histograms_Run05307.root
# Find Keys: 8181
# # of Images (TH2) Files: 101
# # of Waveform (TH2) Files: 8080
# Camera X, Y pixel: 2304 2304
# WARNING: pdestal from 0 to 101
# Debug Image[200,200]: 10 => 103.00 4.52 100.36
# Debug Image[200,200]: 20 => 103.00 3.67 101.00
# Debug Image[200,200]: 30 => 102.00 3.94 101.48
# Debug Image[200,200]: 40 => 102.00 4.49 100.27
# Debug Image[200,200]: 50 => 100.00 4.42 100.20
# Debug Image[200,200]: 60 => 96.00 4.57 99.90
# Debug Image[200,200]: 70 => 94.00 4.40 100.01
# Debug Image[200,200]: 80 => 102.00 4.33 100.16
# Debug Image[200,200]: 90 => 97.00 4.28 100.27
# Debug Image[200,200]: 100 => 104.00 4.34 99.99
# sigma 4.341647
# DONE OUTPUT on files: %s, %s ('/workarea/private/ped/run5307_mean.h5', '/workarea/private/ped/run5307_sigma.h5')
#              varible                                              value
# 0         Run number                                               5310
# 1     RunDescription  Pedestal, random trigger 21 Hz, short exposure...
# 2         Start time                                2021-10-25 11:54:20
# 3          Stop time                                2021-10-25 11:56:03
# 4   Number of events                                                101
# 5       Exposure_sec                                               0.05
# 6           OFFSET_V                                                  0
# 7             GEM3_V                                                440
# 8             GEM2_V                                                440
# 9             GEM1_V                                                440
# 10              T2_V                                                500
# 11              T1_V                                                500
# 12           DRIFT_V                                                840
# 13          HV_STATE                                                  0
# 14    GEMGeometry_id                                                  0
# /workarea/private/ped/run5310_mean.h5 /workarea/private/ped/run5310_sigma.h5
# >>> Pedestal Maker! <<<
# Open file: https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-data/LAB/histograms_Run05310.root
# Find Keys: 8181
# # of Images (TH2) Files: 101
# # of Waveform (TH2) Files: 8080
# Camera X, Y pixel: 2304 2304
# WARNING: pdestal from 0 to 101
# Debug Image[200,200]: 10 => 112.00 6.19 103.55
# Debug Image[200,200]: 20 => 102.00 5.30 101.86
# Debug Image[200,200]: 30 => 98.00 4.57 101.48
# Debug Image[200,200]: 40 => 105.00 4.29 101.37
# Debug Image[200,200]: 50 => 101.00 4.32 101.53
# Debug Image[200,200]: 60 => 97.00 4.43 100.87
# Debug Image[200,200]: 70 => 95.00 4.31 100.66
# Debug Image[200,200]: 80 => 96.00 4.19 100.62
# Debug Image[200,200]: 90 => 96.00 4.17 100.70
# Debug Image[200,200]: 100 => 103.00 4.37 100.85
# sigma 4.366660
# DONE OUTPUT on files: %s, %s ('/workarea/private/ped/run5310_mean.h5', '/workarea/private/ped/run5310_sigma.h5')
#              varible                                              value
# 0         Run number                                               5312
# 1     RunDescription  Pedestal, random trigger 21 Hz, long exposure ...
# 2         Start time                                2021-10-25 12:56:48
# 3          Stop time                                2021-10-25 13:00:41
# 4   Number of events                                                102
# 5       Exposure_sec                                                  1
# 6           OFFSET_V                                                  0
# 7             GEM3_V                                                440
# 8             GEM2_V                                                440
# 9             GEM1_V                                                440
# 10              T2_V                                                500
# 11              T1_V                                                500
# 12           DRIFT_V                                                840
# 13          HV_STATE                                                  1
# 14    GEMGeometry_id                                                  0
# /workarea/private/ped/run5312_mean.h5 /workarea/private/ped/run5312_sigma.h5
# >>> Pedestal Maker! <<<
# Open file: https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-data/LAB/histograms_Run05312.root
# Find Keys: 8262
# # of Images (TH2) Files: 102
# # of Waveform (TH2) Files: 8160
# Camera X, Y pixel: 2304 2304
# WARNING: pdestal from 0 to 102
# Debug Image[200,200]: 10 => 110.00 6.52 105.09
# Debug Image[200,200]: 20 => 92.00 6.11 102.76
# Debug Image[200,200]: 30 => 97.00 5.83 102.90
# Debug Image[200,200]: 40 => 95.00 5.95 102.80
# Debug Image[200,200]: 50 => 120.00 6.37 102.63
# Debug Image[200,200]: 60 => 98.00 6.64 103.15
# Debug Image[200,200]: 70 => 103.00 6.64 103.21
# Debug Image[200,200]: 80 => 99.00 6.90 102.88
# Debug Image[200,200]: 90 => 103.00 6.77 102.79
# Debug Image[200,200]: 100 => 112.00 6.72 102.75
# sigma 6.686630
# DONE OUTPUT on files: %s, %s ('/workarea/private/ped/run5312_mean.h5', '/workarea/private/ped/run5312_sigma.h5')

# %%
df = cy.run_info_logbook(5310, sql=True, verbose=True)

# %%
df
# Out:
#              varible                                              value
# 0         Run number                                               5310
# 1     RunDescription  Pedestal, random trigger 21 Hz, short exposure...
# 2         Start time                                2021-10-25 11:54:20
# 3          Stop time                                2021-10-25 11:56:03
# 4   Number of events                                                101
# 5       Exposure_sec                                               0.05
# 6           OFFSET_V                                                  0
# 7             GEM3_V                                                440
# 8             GEM2_V                                                440
# 9             GEM1_V                                                440
# 10              T2_V                                                500
# 11              T1_V                                                500
# 12           DRIFT_V                                                840
# 13          HV_STATE                                                  0
# 14    GEMGeometry_id                                                  0

# %%
df[df.varible=="RunDescription"].values[0][1]
# Out:
# 'Pedestal, random trigger 21 Hz, short exposure (50 ms)'

# %%
cfile = cy.s3_root_file(5310, "LAB", posix=False)

# %%
dir(cfile)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'split',
#  'splitlines',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'zfill']
