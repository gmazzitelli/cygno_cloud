# %%
L = 1.5E-2 # m
cz = 105   #  GPa 
rho = 2643 #  kg/m^3
H = 5.0E-2 # m 2*h (due volte l'altezza)
# ref https://journals.aps.org/prd/pdf/10.1103/PhysRevD.90.102005

import numpy as np
from IPython.display import Image

Image("picture/BAW_plate_cavity.png")

# %%
S_q=np.pi*L**2
S_n=0.6*3

# %%
print("rapporto superfici: {:.1e}".format(S_q/S_n))
# Out:
# rapporto superfici: 3.9e-04
